# %%
import cv2

# %%
img = cv2.imread('unknown.jpeg')
h,w = img.shape[:2]
print(h,w)
# Out:
# 266 189

# %%
cv2.imwrite('imgs.png',img)
# Out:
# True

# %%
cv2.imshow('image',img)

# %%
from matplotlib import pyplot as plt 
plt.imshow()

# %%
img = cv2.imread('unknown.jpeg')
def converting_into_gray():
    
    grey_img = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    cv2.imwrite('grey_saved1.png',grey_img)

converting_into_gray()
